# %%
using Plots, LaTeXStrings

pyplot(grid=:false)
# Out:
# Plots.PyPlotBackend()

# %%
using PyPlot

# %%
"""
    iteramapeo(f, x0, n)

Esta función itera el mapeo `f`, usando como condición inicial `x0`, `n` veces
y regresa dos vectores que continen la secuencia de puntos, incluyendo las
*visitas* a la diagonal.
"""
function iteramapeo(f, x0, n)
    xx = [x0]
    fx = [0.0]
    for it = 1:n
        x1 = f(x0)
        push!(xx, x0)
        push!(fx, x1)
        x0 = x1
        push!(xx,x1)
        push!(fx,x1)
    end
    xx, fx
end
# Out:
# iteramapeo (generic function with 1 method)

# %% [markdown]
# # Bifurcaciones

# %% [markdown]
# ## Un ejemplo de bifurcación

# %% [markdown]
# Consideremos la *familia* de mapeos cuadráticos dada por
#
# \begin{equation}
#     Q_c(x) = x^2 + c,
# \end{equation}
#
# donde $c\in\mathbb{R}$ es un parámetro. Estudiaremos, por un lado, cómo dependen los puntos fijos de $c$, y su estabilidad.

# %% [markdown]
# Los puntos fijos satisfacen la ecuación $Q_c(x) = x^2+c=x$, de donde obtenemos dos raíces:
#
# \begin{eqnarray}
# p_+(c) & = & \frac{1}{2}( 1 + \sqrt{1-4c} ),\\
# p_-(c) & = & \frac{1}{2}( 1 - \sqrt{1-4c} ).\\
# \end{eqnarray}
#
# De la expresión anterior para las raíces vemos que, si $1-4c<0$ (es decir, $c>1/4$) **no** existen puntos fijos (reales) del mapeo cuadrático. En este caso, *toda* condición inicial termina en infinito.
#
# En cambio, si se satisface que $c<1/4$, entonces existen dos puntos fijos. En este último caso tenemos que $p_+(c)\ge 1/2 \ge p_-(c)$; las igualdades sólo ocurren para $c=1/4$, es decir, en la bifurcación.
#
# Esta *transición* en la que no tenemos puntos fijos ($c>1/4$) a la que tenemos dos ($c<1/4$) al variar un parámetro es lo que se llama una *bifurcación*. En este caso concreto, es una *bifurcación de silla-nodo* (saddle-node) o *bifurcación tangente*.

# %% [markdown]
# ```julia
# Qc(x,c) = x^2 + c       # Mapeo cuadrático
#
# qc1 = x -> Qc(x, 0.5)   # Mapeo cuadrático con c =  0.5
# qc2 = x -> Qc(x, -0.5)  # Mapeo cuadrático con c = -0.5
# qc3 = x -> Qc(x, 0.25)  # Mapeo cuadrático con c =  0.25
#
# domx = -1:1/32:2
#
# p = plot(domx, qc1, xaxis=(L"x", ), yaxis=L"Q_c(x)",
# label=L"Q_{0.5}(x)")
# plot!(domx, qc2, xaxis=(L"x", ), yaxis=L"Q_c(x)",
# label=L"Q_{-0.5}(x)")
# plot!(domx, qc3, xaxis=(L"x"), label=L"Id(x)")
# plot!(domx, identity, xaxis=(L"x"), label=L"Id(x)", color=:red)
# png("fig07-1")
# ```

# %% [markdown]
# ![](fig07-1.png)

# %%
Qc(x,c) = x^2 + c       # Mapeo cuadrático

qc1 = x -> Qc(x, 0.5)   # Mapeo cuadrático con c =  0.5
qc2 = x -> Qc(x, -0.5)  # Mapeo cuadrático con c = -0.5
qc3 = x -> Qc(x, 0.25)  # Mapeo cuadrático con c =  0.25

domx = -1:1/32:2

p = plot(domx, qc1, xaxis=(L"x", ), yaxis=L"Q_c(x)", 
label=L"Q_{0.5}(x)")
plot!(domx, qc2, xaxis=(L"x", ), yaxis=L"Q_c(x)", 
label=L"Q_{-0.5}(x)")
plot!(domx, qc3, xaxis=(L"x"), label=L"Id(x)")
plot!(domx, identity, xaxis=(L"x"), label=L"Id(x)", color=:red)
#png("fig07-1")
# Out:
# [Plots.jl] Initializing backend: pyplot
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M43.3875 247.652
# L413.238 247.652
# L413.238 16.8313
# L43.3875 16.8313
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p4ab70da6a8)" d="
# M43.3875 151.476
# L47.2401 153.843
# L51.0927 156.135
# L54.9453 158.351
# L58.7979 160.493
# L62.6505 162.559
# L66.5031 164.55
# L70.3557 166.466
# L74.2083 168.307
# L78.0609 170.073
# L81.9135 171.763
# L85.7661 173.379
# L89.6187 174.919
# L93.4714 176.384
# L97.324 177.774
# L101.177 179.089
# L105.029 180.329
# L108.882 181.494
# L112.734 182.583
# L116.587 183.597
# L120.44 184.537
# L124.292 185.401
# L128.145 186.19
# L131.997 186.903
# L135.85 187.542
# L139.703 188.106
# L143.555 188.594
# L147.408 189.007
# L151.26 189.345
# L155.113 189.608
# L158.966 189.796
# L162.818 189.909
# L166.671 189.946
# L170.523 189.909
# L174.376 189.796
# L178.229 189.608
# L182.081 189.345
# L185.934 189.007
# L189.786 188.594
# L193.639 188.106
# L197.492 187.542
# L201.344 186.903
# L205.197 186.19
# L209.049 185.401
# L212.902 184.537
# L216.755 183.597
# L220.607 182.583
# L224.46 181.494
# L228.312 180.329
# L232.165 179.089
# L236.018 177.774
# L239.87 176.384
# L243.723 174.919
# L247.576 173.379
# L251.428 171.763
# L255.281 170.073
# L259.133 168.307
# L262.986 166.466
# L266.839 164.55
# L270.691 162.559
# L274.544 160.493
# L278.396 158.351
# L282.249 156.135
# L286.102 153.843
# L289.954 151.476
# L293.807 149.034
# L297.659 146.517
# L301.512 143.925
# L305.365 141.258
# L309.217 138.515
# L313.07 135.698
# L316.922 132.805
# L320.775 129.837
# L324.628 126.794
# L328.48 123.676
# L332.333 120.482
# L336.185 117.214
# L340.038 113.87
# L343.891 110.452
# L347.743 106.958
# L351.596 103.389
# L355.448 99.7447
# L359.301 96.0255
# L363.154 92.231
# L367.006 88.3615
# L370.859 84.4168
# L374.711 80.397
# L378.564 76.302
# L382.417 72.1319
# L386.269 67.8867
# L390.122 63.5664
# L393.974 59.1708
# L397.827 54.7002
# L401.68 50.1544
# L405.532 45.5335
# L409.385 40.8375
# L413.237 36.0663" style="fill:none;stroke:#009afa;stroke-linecap:round;"/>
#    </g>
#    <g id="line2d_2">
#     <path clip-path="url(#p4ab70da6a8)" d="
# M43.3875 189.946
# L47.2401 192.313
# L51.0927 194.605
# L54.9453 196.822
# L58.7979 198.963
# L62.6505 201.029
# L66.5031 203.02
# L70.3557 204.936
# L74.2083 206.777
# L78.0609 208.543
# L81.9135 210.233
# L85.7661 211.849
# L89.6187 213.389
# L93.4714 214.854
# L97.324 216.244
# L101.177 217.559
# L105.029 218.799
# L108.882 219.964
# L112.734 221.053
# L116.587 222.067
# L120.44 223.007
# L124.292 223.871
# L128.145 224.66
# L131.997 225.373
# L135.85 226.012
# L139.703 226.576
# L143.555 227.064
# L147.408 227.477
# L151.26 227.815
# L155.113 228.078
# L158.966 228.266
# L162.818 228.379
# L166.671 228.417
# L170.523 228.379
# L174.376 228.266
# L178.229 228.078
# L182.081 227.815
# L185.934 227.477
# L189.786 227.064
# L193.639 226.576
# L197.492 226.012
# L201.344 225.373
# L205.197 224.66
# L209.049 223.871
# L212.902 223.007
# L216.755 222.067
# L220.607 221.053
# L224.46 219.964
# L228.312 218.799
# L232.165 217.559
# L236.018 216.244
# L239.87 214.854
# L243.723 213.389
# L247.576 211.849
# L251.428 210.233
# L255.281 208.543
# L259.133 206.777
# L262.986 204.936
# L266.839 203.02
# L270.691 201.029
# L274.544 198.963
# L278.396 196.822
# L282.249 194.605
# L286.102 192.313
# L289.954 189.946
# L293.807 187.505
# L297.659 184.987
# L301.512 182.395
# L305.365 179.728
# L309.217 176.985
# L313.07 174.168
# L316.922 171.275
# L320.775 168.307
# L324.628 165.264
# L328.48 162.146
# L332.333 158.953
# L336.185 155.684
# L340.038 152.341
# L343.891 148.922
# L347.743 145.428
# L351.596 141.859
# L355.448 138.215
# L359.301 134.496
# L363.154 130.701
# L367.006 126.832
# L370.859 122.887
# L374.711 118.867
# L378.564 114.772
# L382.417 110.602
# L386.269 106.357
# L390.122 102.036
# L393.974 97.6409
# L397.827 93.1703
# L401.68 88.6245
# L405.532 84.0036
# L409.385 79.3075
# L413.237 74.5363" style="fill:none;stroke:#e36f47;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M43.3875 16.8313
# L413.237 16.8313" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M413.238 247.652
# L413.238 16.8313" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M43.3875 247.652
# L413.237 247.652" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M43.3875 247.652
# L43.3875 16.8313" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="43.3875" xlink:href="#m93b0483c22" y="247.6515625"/>
#       </g>
#      </g>
#      <g id="line2d_4">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="43.3875" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −1.0 -->
#       <defs>
#        <path d="
# M10.5938 35.5
# L73.1875 35.5
# L73.1875 27.2031
# L10.5938 27.2031
# z
# " id="BitstreamVeraSans-Roman-2212"/>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#       </defs>
#       <g transform="translate(34.36375 257.7303125)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="147.412109375" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="179.19921875" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="105.029166667" xlink:href="#m93b0483c22" y="247.6515625"/>
#       </g>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="105.029166667" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- −0.5 -->
#       <defs>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.015

# %% [markdown]
# Como hemos visto, la derivada del mapeo evaluada en los puntos fijos da información sobre el caracter atractivo o repulsivo del punto fijo. En el caso del mapeo cuadrático tenemos que $Q_c'(x) = 2x$.
#
# Por lo tanto, el punto fijo $p_+(c)$ *siempre* es repulsivo.
#
# En cuanto a $p_-(c)$, el punto será atractivo si se cumple $|Q_c'(p_-(c))| = 2 |p_-(c)|<1$. De aquí es fácil obtener
# que debe cumplirse la desigualdad
#
# \begin{equation}
# -1 < 1 - \sqrt{1-4c} < 1,
# \end{equation}
#
# que equivale a $2 > \sqrt{1-4c} > 0$, lo que nos conduce a la condición $1/4 > c > -3/4$ para que $p_-(c)$ sea un punto atractivo.

# %% [markdown]
# Todo esto se puede resumir con el siguiente *diagrama de bifurcación*.

# %% [markdown]
# ```julia
# pplus(c) = 0.5*(1+sqrt(1-4*c))
# pminus(c) = 0.5*(1-sqrt(1-4*c))
#
# domc = -2:1/64:1/4
#
# plot(-2:1/64:1/4, pplus, xaxis=(L"c", (-2,1)), yaxis=(L"p_\pm(c)"), label=L"p_+(c)", color=:red)
# plot!(-3/4:1/64:1/4, pminus, label=L"p_-(c)", color=:blue)
# plot!(-2:1/64:-3/4, pminus, label="", color=:red, line=(:dash))
# png("fig07-2")
# ```

# %% [markdown]
# ![](./fig07-2.png)

# %%
pplus(c) = 0.5*(1+sqrt(1-4*c))
pminus(c) = 0.5*(1-sqrt(1-4*c))

domc = -2:1/64:1/4

plot(-2:1/64:1/4, pplus, xaxis=(L"c", (-2,1)), yaxis=(L"p_\pm(c)"), label=L"p_+(c)", color=:red)
plot!(-3/4:1/64:1/4, pminus, label=L"p_-(c)", color=:blue)
plot!(-2:1/64:-3/4, pminus, label="", color=:red, line=(:dash))
#png("fig07-2")
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M51.1175 247.652
# L413.384 247.652
# L413.384 16.8312
# L51.1175 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#pa66629ba55)" d="
# M51.1175 16.8312
# L73.7591 21.7446
# L96.4008 26.8868
# L117.156 31.8316
# L136.024 36.5484
# L153.005 41.0017
# L169.986 45.6838
# L185.081 50.0693
# L200.175 54.7025
# L213.383 58.9966
# L224.703 62.8885
# L236.024 67.0123
# L245.458 70.6593
# L254.892 74.5363
# L262.439 77.8365
# L269.987 81.3503
# L277.534 85.1254
# L283.194 88.1684
# L288.855 91.4378
# L294.515 94.9929
# L298.289 97.565
# L302.062 100.344
# L305.836 103.389
# L309.61 106.796
# L311.496 108.683
# L313.383 110.736
# L315.27 113.006
# L317.157 115.583
# L319.044 118.64
# L320.93 122.624
# L322.817 132.241
# L322.817 132.241" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="line2d_2">
#     <path clip-path="url(#pa66629ba55)" d="
# M202.062 209.182
# L203.949 208.578
# L205.835 207.97
# L207.722 207.357
# L209.609 206.738
# L211.496 206.115
# L213.383 205.486
# L215.269 204.852
# L217.156 204.212
# L219.043 203.567
# L220.93 202.915
# L222.817 202.258
# L224.703 201.594
# L226.59 200.924
# L228.477 200.247
# L230.364 199.564
# L232.251 198.873
# L234.137 198.176
# L236.024 197.471
# L237.911 196.758
# L239.798 196.037
# L241.685 195.308
# L243.571 194.57
# L245.458 193.824
# L247.345 193.068
# L249.232 192.303
# L251.119 191.528
# L253.005 190.742
# L254.892 189.946
# L256.779 189.139
# L258.666 188.321
# L260.553 187.49
# L262.439 186.646
# L264.326 185.789
# L266.213 184.919
# L268.1 184.033
# L269.987 183.133
# L271.873 182.215
# L273.76 181.281
# L275.647 180.329
# L277.534 179.357
# L279.421 178.365
# L281.308 177.352
# L283.194 176.314
# L285.081 175.252
# L286.968 174.163
# L288.855 173.045
# L290.742 171.895
# L292.628 170.711
# L294.515 169.49
# L296.402 168.227
# L298.289 166.918
# L300.176 165.557
# L302.062 164.139
# L303.949 162.655
# L305.836 161.094
# L307.723 159.444
# L309.61 157.687
# L311.496 155.799
# L313.383 153.747
# L315.27 151.476
# L317.157 148.899
# L319.044 145.843
# L320.93 141.859
# L322.817 132.241" style="fill:none;stroke:#0000ff;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M51.1175 16.8312
# L413.384 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M413.384 247.652
# L413.384 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M51.1175 247.652
# L413.384 247.652" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M51.1175 247.652
# L51.1175 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="51.1175" xlink:href="#m93b0483c22" y="247.6515625"/>
#       </g>
#      </g>
#      <g id="line2d_4">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="51.1175" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −2.0 -->
#       <defs>
#        <path d="
# M10.5938 35.5
# L73.1875 35.5
# L73.1875 27.2031
# L10.5938 27.2031
# z
# " id="BitstreamVeraSans-Roman-2212"/>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#       </defs>
#       <g transform="translate(42.09375 257.7303125)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-32"/>
#        <use x="147.412109375" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="179.19921875" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="111.495208333" xlink:href="#m93b0483c22" y="247.6515625"/>
#       </g>
#      </g>
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="111.495208333" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- −1.5 -->
#       <defs>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.0156
# Q14.8906 38.1406 10.7969 36.2812
# z
# " id="BitstreamVeraSans-Roman-35"/>
#       </defs>
#       <g transform="translate(102.555208333 257.7303125)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="147.412109375" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="179.19921875" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="171.872916667" xlink:href="#m93b0483c22" y="247.6515625"/>
#       </g>
#      </g>
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="171.872916667" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- −1.0 -->
#       <g transform="translate(162.849166667 257.7303125)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans

# %% [markdown]
# El diagrama de bifurcación anterior fue obtenido a partir de la dependencia de los puntos fijos del parámetro $c$. Uno puede obtener la parte estable de este diagrama de bifurcación de manera numérica, iterando el mapeo varias veces y usando una condición inicial $x_0$ que esté en la cuenca de atracción de $p_-(c)$.

# %% [markdown]
# **Ejercicio 1:**
#
# - Obtengan el diagrama de bifurcación anterior del mapeo $Q_c(x)$ a partir de la iteración de una condición inicial.
#
# - Caractericen la cuenca de atracción de $p_-(c)$ cuando el punto es estable.
#
# - ¿Qué pasa si $c < -3/4$ con el diagrama de bifurcaciones?

# %%
function bif_qc(n::Int64, x::Float64, c::Float64) #n es el número de iteraciones
    
    Qc = x^2 + c       

    qc_c = Float64[] 
    qc_p = Float64[]
    
    push!(qc_c, c)
    push!(qc_p, Qc)
    
    for i in 1:n-1
        #push!(qc_c,c)
        Qc = Qc^2 + c
        if i > 400
            push!(qc_c,c)
            push!(qc_p,Qc)
        end
    end
    
 
    return qc_c, qc_p
end
#Ahora debo variar la c para que corra
# Out:
# bif_qc (generic function with 1 method)

# %%
c=0.25
pplus(c) = 0.5*(1+sqrt(1-4*c))
pminus(c) = 0.5*(1-sqrt(1-4*c))
# Out:
# pminus (generic function with 1 method)

# %%
pminus(c)
# Out:
# 0.5

# %%
x100, y100=bif_qc(500, 0.0, -0.85)
# Out:
# ([-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85  …  -0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85,-0.85],[-0.85,-0.183772,-0.816228,-0.183772,-0.816228,-0.183772,-0.816228,-0.183772,-0.816228,-0.183772  …  -0.183772,-0.816228,-0.183772,-0.816228,-0.183772,-0.816228,-0.183772,-0.816228,-0.183772,-0.816228])

# %%
y100[end]
# Out:
# -0.816227766016838

# %%
scatter(x100,y100)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M35.09 263.298
# L405.061 263.298
# L405.061 16.8313
# L35.09 16.8313
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="PathCollection_1">
#     <defs>
#      <path d="
# M0 3
# C0.795609 3 1.55874 2.6839 2.12132 2.12132
# C2.6839 1.55874 3 0.795609 3 0
# C3 -0.795609 2.6839 -1.55874 2.12132 -2.12132
# C1.55874 -2.6839 0.795609 -3 0 -3
# C-0.795609 -3 -1.55874 -2.6839 -2.12132 -2.12132
# C-2.6839 -1.55874 -3 -0.795609 -3 0
# C-3 0.795609 -2.6839 1.55874 -2.12132 2.12132
# C-1.55874 2.6839 -0.795609 3 0 3
# z
# " id="m996acb2787" style="stroke:#000000;"/>
#     </defs>
#     <g clip-path="url(#p1ce13bddce)">
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="247.893359375"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.488714545"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="42.6400354549"/>
#      <use style="fill:#009afa;stroke:#000000;" x="220.075625" xlink:href="#m996acb2787" y="237.48871

# %%
(x101, y101)=bif_qc(500, -0.1, 0.25)
# Out:
# ([0.26,0.26,0.3176,0.35087,0.37311,0.389211,0.401485,0.41119,0.419077,0.425626  …  0.497996,0.498,0.498004,0.498008,0.498012,0.498016,0.49802,0.498024,0.498028,0.498032],[0.26,0.3176,0.35087,0.37311,0.389211,0.401485,0.41119,0.419077,0.425626,0.431157  …  0.498,0.498004,0.498008,0.498012,0.498016,0.49802,0.498024,0.498028,0.498032,0.498036])

# %%
scatter(x101,y101)
# Out:
# LoadError: UndefVarError: scatter not defined
# while loading In[140], in expression starting on line 1

# %%
plot(c, pminus)
# Out:
# LoadError: MethodError: `convertToAnyVector` has no method matching convertToAnyVector(::Float64, ::Dict{Symbol,Any})
# Closest candidates are:
#   convertToAnyVector(!Matched::Void, ::Dict{Symbol,Any})
#   convertToAnyVector(!Matched::Integer, ::Dict{Symbol,Any})
#   convertToAnyVector{T<:Number}(!Matched::AbstractArray{T<:Number,1}, ::Dict{Symbol,Any})
#   ...
# while loading In[121], in expression starting on line 1
#
#  in build_series_args at /Users/Yuriko/.julia/v0.4/Plots/src/series_args.jl:108
#  in _add_series at /Users/Yuriko/.julia/v0.4/Plots/src/plot.jl:178
#  in plot! at /Users/Yuriko/.julia/v0.4/Plots/src/plot.jl:105
#  in plot at /Users/Yuriko/.julia/v0.4/Plots/src/plot.jl:56

# %%
plot(-10:1/64:1/4, pminus)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M35.0075 263.298
# L417.189 263.298
# L417.189 16.8312
# L35.0075 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p2ece6cdaba)" d="
# M35.0075 242.282
# L55.908 234.945
# L75.8133 227.721
# L94.7233 220.621
# L112.638 213.658
# L129.558 206.848
# L145.979 199.997
# L161.406 193.318
# L175.837 186.833
# L189.771 180.328
# L202.709 174.047
# L215.15 167.76
# L226.596 161.736
# L237.544 155.73
# L247.994 149.744
# L257.947 143.781
# L266.904 138.163
# L275.364 132.608
# L283.326 127.125
# L290.79 121.724
# L297.757 116.419
# L304.226 111.226
# L310.198 106.166
# L315.672 101.261
# L321.146 96.0525
# L326.122 91.0013
# L330.601 86.1411
# L334.582 81.5152
# L338.563 76.5318
# L342.046 71.802
# L345.032 67.397
# L348.018 62.5697
# L350.506 58.118
# L352.497 54.1765
# L354.487 49.7667
# L355.98 46.0254
# L357.473 41.7281
# L358.468 38.3926
# L359.463 34.436
# L360.459 29.2797
# L360.956 25.6336
# L361.454 16.8312
# L361.454 16.8312" style="fill:none;stroke:#009afa;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M35.0075 16.8312
# L417.189 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M417.189 263.298
# L417.189 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M35.0075 263.298
# L417.189 263.298" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M35.0075 263.298
# L35.0075 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="35.0075" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="35.0075" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- −10 -->
#       <defs>
#        <path d="
# M10.5938 35.5
# L73.1875 35.5
# L73.1875 27.2031
# L10.5938 27.2031
# z
# " id="BitstreamVeraSans-Roman-2212"/>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#       </defs>
#       <g transform="translate(27.255 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="147.412109375" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="98.704375" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="98.704375" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- −8 -->
#       <defs>
#        <path d="
# M31.7812 34.625
# Q24.75 34.625 20.7188 30.8594
# Q16.7031 27.0938 16.7031 20.5156
# Q16.7031 13.9219 20.7188 10.1562
# Q24.75 6.39062 31.7812 6.39062
# Q38.8125 6.39062 42.8594 10.1719
# Q46.9219 13.9688 46.9219 20.5156
# Q46.9219 27.0938 42.8906 30.8594
# Q38.875 34.625 31.7812 34.625
# M21.9219 38.8125
# Q15.5781 40.375 12.0312 44.7188
# Q8.5 49.0781 8.5 55.3281
# Q8.5 64.0625 14.7188 69.1406
# Q20.9531 74.2188 31.7812 74.2188
# Q42.6719 74.2188 48.875 69.1406
# Q55.0781 64.0625 55.0781 55.3281
# Q55.0781 49.0781 51.5312 44.7188
# Q48 40.375 41.7031 38.8125
# Q48.8281 37.1562 52.7969 32.3125
# Q56.7812 27.4844 56.7812 20.5156
# Q56.7812 9.90625 50.3125 4.23438
# Q43.8438 -1.42188 31.7812 -1.42188
# Q19.7344 -1.42188 13.25 4.23438
# Q6.78125 9.90625 6.78125 20.5156
# Q6.78125 27.4844 10.7812 32.3125
# Q14.7969 37.1562 21.9219 38.8125
# M18.3125 54.3906
# Q18.3125 48.7344 21.8438 45.5625
# Q25.3906 42.3906 31.7812 42.3906
# Q38.1406 42.3906 41.7188 45.5625
# Q45.3125 48.7344 45.3125 54.3906
# Q45.3125 60.0625 41.7188 63.2344
# Q38.1406 66.4062 31.7812 66.4062
# Q25.3906 66.4062 21.8438 63.2344
# Q18.3125 60.0625 18.3125 54.3906" id="BitstreamVeraSans-Roman-38"/>
#       </defs>
#       <g transform="translate(93.505 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-38"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="162.40125" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="162.40125" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- −6 -->
#       <defs>
#        <path d="
# M33.0156 40.375
# Q26.375 40.375 22.4844 35.8281
# Q18.6094 31.2969 18.6094 23.3906
# Q18.6094 15.5312 22.4844 10.9531
# Q26.375 6.39062 33.0156 6.39062
# Q39.6562 6.39062 43.5312 10.9531
# Q47.4062 15.5312 47.4062 23.3906
# Q47.4062 31.2969 43.5312 35.8281
# Q39.6562 40.375 33.0156 40.375
# M52.5938 71.2969
# L52.5938 62.3125
# Q48.875 64.0625 45.0938 64.9844
# Q41.3125 65.9219 37.5938 65.9219
# Q27.8281 65.9219 22.6719 59.3281
# Q17.5312 52.7344 16.7969 39.4062
# Q19.6719 43.6562 24.0156 45.9219
# Q28.375 48.1875 33.5938 48.1875
# Q44.5781 48.1875 50.9531 41.5156
# Q57.3281 34.8594 57.3281 23.3906
# Q57.3281 12.1562 50.6875 5.35938
# Q44.0469 -1.42188 33.0156 -1.42188
# Q20.3594 -1.42188 13.6719 8.26562
# Q6.98438 17.9688 6.98438 36.375
# Q6.98438 53.6562 15.1875 63.9375
# Q23.3906 74.2188 37.2031 74.2188
# Q40.9219 74.2188 44.7031 73.4844
# Q48.4844 72.75 52.5938 71.2969" id="BitstreamVeraSans-Roman-36"/>
#       </defs>
#       <g transform="translate(157.18 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-2212"/>
#        <use x="83.7890625" xlink:href="#BitstreamVeraSans-Roman-36"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="226.098125" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="226.098125" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- −4 -->
#       <defs>
#        <path d="
# M37.7969 64.3125
# L12.8906 25.3906
# L37.7969 25.3906
# z
#
# M35.2031 72.9062
# L47.6094 72.9062
# L47.6094 25.3906
# L58.0156 25.3906
# L58.0156 17.1875
# L47.6094 17.1875
# L47.6094 0

# %%
?Dict
# Out:
# search: Dict directed_curve DirectIndexString WeakKeyDict redirect_stdin
# ```rst
# ..  Dict([itr])
#
# ``Dict{K,V}()`` constructs a hash table with keys of type ``K`` and values of type ``V``.
#
# Given a single iterable argument, constructs a :obj:`Dict` whose key-value pairs
# are taken from 2-tuples ``(key,value)`` generated by the argument.
#
# .. doctest::
#
#   julia> Dict([("A", 1), ("B", 2)])
#   Dict{ASCIIString,Int64} with 2 entries:
#     "B" => 2
#     "A" => 1
#
# Alternatively, a sequence of pair arguments may be passed.
#
# .. doctest::
#
#   julia> Dict("A"=>1, "B"=>2)
#   Dict{ASCIIString,Int64} with 2 entries:
#     "B" => 2
#     "A" => 1
# ```

# %%
(x1, y1)=bif_qc(900, 0.0, 0.25)
# Out:
# ([0.25,0.25,0.3125,0.347656,0.370865,0.387541,0.400188,0.41015,0.418223,0.424911  …  0.498888,0.49889,0.498891,0.498892,0.498893,0.498895,0.498896,0.498897,0.498898,0.498899],[0.25,0.3125,0.347656,0.370865,0.387541,0.400188,0.41015,0.418223,0.424911,0.430549  …  0.49889,0.498891,0.498892,0.498893,0.498895,0.498896,0.498897,0.498898,0.498899,0.498901])

# %%
(x2, y2)=bif_qc(100, 0.0, 0.5)
# Out:
# ([0.5,0.5,0.75,1.0625,1.62891,3.15334,10.4435,109.567,12005.5,1.44131e8  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf],[0.5,0.75,1.0625,1.62891,3.15334,10.4435,109.567,12005.5,1.44131e8,2.07739e16  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf])

# %%
(x10, y10)=bif_qc(900, 0.1, 0.25)
# Out:
# ([0.26,0.26,0.3176,0.35087,0.37311,0.389211,0.401485,0.41119,0.419077,0.425626  …  0.498887,0.498889,0.49889,0.498891,0.498892,0.498893,0.498895,0.498896,0.498897,0.498898],[0.26,0.3176,0.35087,0.37311,0.389211,0.401485,0.41119,0.419077,0.425626,0.431157  …  0.498889,0.49889,0.498891,0.498892,0.498893,0.498895,0.498896,0.498897,0.498898,0.4989])

# %%
(x11, y11)=bif_qc(900, -2.0, 0.25)
# Out:
# ([4.25,4.25,18.3125,335.598,112626.0,1.26846e10,1.609e20,2.58887e40,6.70225e80,4.49202e161  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf],[4.25,18.3125,335.598,112626.0,1.26846e10,1.609e20,2.58887e40,6.70225e80,4.49202e161,Inf  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf])

# %%
#Gráfica
#graf cvs.p
plot(x1,y1, color=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M33.7138 263.298
# L410.663 263.298
# L410.663 16.8312
# L33.7138 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p9ca19582d1)" d="
# M33.7138 263.298
# L33.7138 201.681
# L127.951 167.022
# L180.96 144.141
# L215.953 127.701
# L241.097 115.233
# L260.167 105.411
# L275.188 97.4521
# L297.444 85.3005
# L313.218 76.4275
# L329.889 66.8154
# L347.631 56.3213
# L365.325 45.5838
# L383.129 34.5053
# L400.729 23.2835
# L409.004 17.9151
# L409.004 17.9151" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M33.7138 16.8312
# L410.663 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M410.663 263.298
# L410.663 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M33.7138 263.298
# L410.663 263.298" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M33.7138 263.298
# L33.7138 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="33.71375" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="33.71375" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0.25 -->
#       <defs>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.0156
# Q14.8906 38.1406 10.7969 36.2812
# z
# " id="BitstreamVeraSans-Roman-35"/>
#       </defs>
#       <g transform="translate(25.420625 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-32"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="109.103625" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="109.103625" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0.30 -->
#       <defs>
#        <path d="
# M40.5781 39.3125
# Q47.6562 37.7969 51.625 33
# Q55.6094 28.2188 55.6094 21.1875
# Q55.6094 10.4062 48.1875 4.48438
# Q40.7656 -1.42188 27.0938 -1.42188
# Q22.5156 -1.42188 17.6562 -0.515625
# Q12.7969 0.390625 7.625 2.20312
# L7.625 11.7188
# Q11.7188 9.32812 16.5938 8.10938
# Q21.4844 6.89062 26.8125 6.89062
# Q36.0781 6.89062 40.9375 10.5469
# Q45.7969 14.2031 45.7969 21.1875
# Q45.7969 27.6406 41.2812 31.2656
# Q36.7656 34.9062 28.7188 34.9062
# L20.2188 34.9062
# L20.2188 43.0156
# L29.1094 43.0156
# Q36.375 43.0156 40.2344 45.9219
# Q44.0938 48.8281 44.0938 54.2969
# Q44.0938 59.9062 40.1094 62.9062
# Q36.1406 65.9219 28.7188 65.9219
# Q24.6562 65.9219 20.0156 65.0312
# Q15.375 64.1562 9.8125 62.3125
# L9.8125 71.0938
# Q15.4375 72.6562 20.3438 73.4375
# Q25.25 74.2188 29.5938 74.2188
# Q40.8281 74.2188 47.3594 69.1094
# Q53.9062 64.0156 53.9062 55.3281
# Q53.9062 49.2656 50.4375 45.0938
# Q46.9688 40.9219 40.5781 39.3125" id="BitstreamVeraSans-Roman-33"/>
#       </defs>
#       <g transform="translate(100.72675 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-33"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="184.4935" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="184.4935" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 0.35 -->
#       <g transform="translate(176.200375 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-33"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="259.883375" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="259.883375" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 0.40 -->
#       <defs>
#        <path d="
# M37.7969 64.3125
# L12.8906 25.3906
# L37.7969 25.3906
# z
#
# M35.2031 72.9062
# L47.6094 72.9062
# L47.6094 25.3906
# L58.0156 25.3906
# L58.0156 17.1875
# L47.6094 17.1875
# L47.6094 0
# L37.7969 0
# L37.7969 17.1875
# L4.89062 17.1875
# L4.89062 26.7031
# z
# " id="BitstreamVe

# %%
plot(x10,y10, color=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M33.7138 263.298
# L410.663 263.298
# L410.663 16.8312
# L33.7138 16.8312
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p9ca19582d1)" d="
# M48.7917 253.439
# L48.7917 196.653
# L135.641 163.854
# L185.805 141.928
# L219.338 126.054
# L243.615 113.954
# L262.122 104.386
# L276.756 96.61
# L298.522 84.7008
# L320.204 72.4289
# L338.524 61.7425
# L357.209 50.5426
# L375.291 39.4166
# L392.992 28.2498
# L409.002 17.9162
# L409.002 17.9162" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M33.7138 16.8312
# L410.663 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M410.663 263.298
# L410.663 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M33.7138 263.298
# L410.663 263.298" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M33.7138 263.298
# L33.7138 16.8312" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="33.71375" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="33.71375" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0.25 -->
#       <defs>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.0156
# Q14.8906 38.1406 10.7969 36.2812
# z
# " id="BitstreamVeraSans-Roman-35"/>
#       </defs>
#       <g transform="translate(25.420625 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-32"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="109.103625" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="109.103625" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0.30 -->
#       <defs>
#        <path d="
# M40.5781 39.3125
# Q47.6562 37.7969 51.625 33
# Q55.6094 28.2188 55.6094 21.1875
# Q55.6094 10.4062 48.1875 4.48438
# Q40.7656 -1.42188 27.0938 -1.42188
# Q22.5156 -1.42188 17.6562 -0.515625
# Q12.7969 0.390625 7.625 2.20312
# L7.625 11.7188
# Q11.7188 9.32812 16.5938 8.10938
# Q21.4844 6.89062 26.8125 6.89062
# Q36.0781 6.89062 40.9375 10.5469
# Q45.7969 14.2031 45.7969 21.1875
# Q45.7969 27.6406 41.2812 31.2656
# Q36.7656 34.9062 28.7188 34.9062
# L20.2188 34.9062
# L20.2188 43.0156
# L29.1094 43.0156
# Q36.375 43.0156 40.2344 45.9219
# Q44.0938 48.8281 44.0938 54.2969
# Q44.0938 59.9062 40.1094 62.9062
# Q36.1406 65.9219 28.7188 65.9219
# Q24.6562 65.9219 20.0156 65.0312
# Q15.375 64.1562 9.8125 62.3125
# L9.8125 71.0938
# Q15.4375 72.6562 20.3438 73.4375
# Q25.25 74.2188 29.5938 74.2188
# Q40.8281 74.2188 47.3594 69.1094
# Q53.9062 64.0156 53.9062 55.3281
# Q53.9062 49.2656 50.4375 45.0938
# Q46.9688 40.9219 40.5781 39.3125" id="BitstreamVeraSans-Roman-33"/>
#       </defs>
#       <g transform="translate(100.72675 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-33"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="184.4935" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="184.4935" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 0.35 -->
#       <g transform="translate(176.200375 273.37625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-33"/>
#        <use x="159.033203125" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="259.883375" xlink:href="#m93b0483c22" y="263.2975"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="259.883375" xlink:href="#m741efc42ff" y="16.83125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 0.40 -->
#       <defs>
#        <path d="
# M37.7969 64.3125
# L12.8906 25.3906
# L37.7969 25.3906
# z
#
# M35.2031 72.9062
# L47.6094 72.9062
# L47.6094 25.3906
# L58.0156 25.3906
# L58.0156 17.1875
# L47.6094 17.1875
# L47.6094 0
# L37.7969 0
# L37.7969 17.1875
# L4.89062 17.1875
# L4.89062 26.7031
# z
# " id="BitstreamVeraSans-Roman-34"/>

# %%
plot(x11,y11, color=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M28.76 248.684
# L417.165 248.684
# L417.165 25.0781
# L28.76 25.0781
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#p27ec9fad5f)" d="
# M28.76 248.684
# L400.644 25.4747
# L400.644 25.4747" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M28.76 25.0781
# L417.165 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M417.165 248.684
# L417.165 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M28.76 248.684
# L417.165 248.684" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M28.76 248.684
# L28.76 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.76" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.76" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0 -->
#       <defs>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#       </defs>
#       <g transform="translate(26.744375 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="84.2464285714" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="84.2464285714" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 1 -->
#       <defs>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#       </defs>
#       <g transform="translate(82.5101785714 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-31"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="139.732857143" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="139.732857143" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 2 -->
#       <defs>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#       </defs>
#       <g transform="translate(137.881607143 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-32"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="195.219285714" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="195.219285714" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 3 -->
#       <defs>
#        <path d="
# M40.5781 39.3125
# Q47.6562 37.7969 51.625 33
# Q55.6094 28.2188 55.6094 21.1875
# Q55.6094 10.4062 48.1875 4.48438
# Q40.7656 -1.42188 27.0938 -1.42188
# Q22.5156 -1.42188 17.6562 -0.515625
# Q12.7969 0.390625 7.625 2.20312
# L7.625 11.7188
# Q11.7188 9.32812 16.5938 8.10938
# Q21.4844 6.89062 26.8125 6.89062
# Q36.0781 6.89062 40.9375 10.5469
# Q45.7969 14.2031 45.7969 21.1875
# Q45.7969 27.6406 41.2812 31.2656
# Q36.7656 34.9062 28.7188 34.9062
# L20.2188 34.9062
# L20.2188 43.0156
# L29.1094 43.0156
# Q36.375 43.0156 40.2344 45.9219
# Q44.0938 48.8281 44.0938 54.2969
# Q44.0938 59.9062 40.1094 62.9062
# Q36.1406 65.9219 28.7188 65.9219
# Q24.6562 65.9219 20.0156 65.0312
# Q15.375 64.1562 9.8125 62.3125
# L9.8125 71.0938
# Q15.4375 72.6562 20.3438 73.4375
# Q25.25 74.2188 29.5938 74.2188
# Q40.8281 74.2188 47.3594 69.1094
# Q53.9062 64.0156 53.9062 55.3281
# Q53.9062 49.2656 50.4375 45.0938
# Q46.9688 40.9219 40.5781 39.3125" id="BitstreamVeraSans-Roman-33"/>
#       </defs>
#       <g transform="translate(193.299910714 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-33"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="250.705714286" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="250.705714286" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 4 -->
#       <defs>
#        <path d="
# M37.7969 64.3125
# L12.8906 25.3906
# L37.7969 25.3906
# z
#
# M35.2031 72.9062
# L47.6094 72.9062
# L47.6094 25.3906
# L58.0156 25.3906
# L58.0156 17.1875
# L47.6094 17.1875
# L47.6094 0
# L37.7969 0
# L37.7969 17.1875
# L4.89062 17.1875
# L4.89062 26.7031
# z
# " id="BitstreamVeraSans-Roman-34"/>
#       </defs>
#       <g transform="translate(248.580714286 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-34"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="306.192142857" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_13">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="306.192142857" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_6">
#       <!-- 5 -->
#       <defs>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.

# %%
plot(x2,y2, color=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M28.7063 248.684
# L413.333 248.684
# L413.333 25.0781
# L28.7063 25.0781
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#pc932c5e90b)" d="
# M28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L409.87 56.5365" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M28.7063 25.0781
# L413.333 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M413.333 248.684
# L413.333 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M28.7063 248.684
# L413.333 248.684" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M28.7063 248.684
# L28.7063 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.70625" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.70625" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0.0 -->
#       <defs>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#       </defs>
#       <g transform="translate(22.874375 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="83.6529464286" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="83.6529464286" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0.5 -->
#       <defs>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.0156
# Q14.8906 38.1406 10.7969 36.2812
# z
# " id="BitstreamVeraSans-Roman-35"/>
#       </defs>
#       <g transform="translate(77.9048214286 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="138.599642857" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="138.599642857" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 1.0 -->
#       <defs>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#       </defs>
#       <g transform="translate(132.943392857 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="193.546339286" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="193.546339286" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 1.5 -->
#       <g transform="translate(187.973839286 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="248.493035714" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="248.493035714" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 2.0 -->
#       <defs>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#       </defs>
#       <g transform="translate(242.690535714 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-32"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="303.439732143" xlink:href="#m93b0483c22" y="248.68375"/>

# %%
(x3, y3)=bif_qc(100, -1.0, 0.25)
# Out:
# ([1.25,1.25,1.8125,3.53516,12.7473,162.744,26486.0,7.01508e8,4.92113e17,2.42176e35  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf],[1.25,1.8125,3.53516,12.7473,162.744,26486.0,7.01508e8,4.92113e17,2.42176e35,5.8649e70  …  Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf,Inf])

# %%
plot(c,Qc)
# Out:
# LoadError: UndefVarError: c not defined
# while loading In[73], in expression starting on line 1

# %%
plot(x3,y3, color=:red)
# Out:
# <?xml version="1.0" encoding="utf-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Created with matplotlib (http://matplotlib.org/) -->
# <svg height="288pt" version="1.1" viewBox="0 0 432 288" width="432pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#  <defs>
#   <style type="text/css">
# *{stroke-linecap:butt;stroke-linejoin:round;}
#   </style>
#  </defs>
#  <g id="figure_1">
#   <g id="patch_1">
#    <path d="
# M0 288
# L432 288
# L432 0
# L0 0
# z
# " style="fill:#ffffff;"/>
#   </g>
#   <g id="axes_1">
#    <g id="patch_2">
#     <path d="
# M28.7063 248.684
# L413.333 248.684
# L413.333 25.0781
# L28.7063 25.0781
# z
# " style="fill:#ffffff;"/>
#    </g>
#    <g id="line2d_1">
#     <path clip-path="url(#pa6d3e6d7ec)" d="
# M28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L28.7063 248.684
# L406.707 28.2167" style="fill:none;stroke:#ff0000;stroke-linecap:round;"/>
#    </g>
#    <g id="patch_3">
#     <path d="
# M28.7063 25.0781
# L413.333 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_4">
#     <path d="
# M413.333 248.684
# L413.333 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_5">
#     <path d="
# M28.7063 248.684
# L413.333 248.684" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="patch_6">
#     <path d="
# M28.7063 248.684
# L28.7063 25.0781" style="fill:none;stroke:#000000;stroke-linecap:square;stroke-linejoin:miter;"/>
#    </g>
#    <g id="matplotlib.axis_1">
#     <g id="xtick_1">
#      <g id="line2d_2">
#       <defs>
#        <path d="
# M0 0
# L0 -4" id="m93b0483c22" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.70625" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_3">
#       <defs>
#        <path d="
# M0 0
# L0 4" id="m741efc42ff" style="stroke:#000000;stroke-width:0.5;"/>
#       </defs>
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="28.70625" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_1">
#       <!-- 0.0 -->
#       <defs>
#        <path d="
# M31.7812 66.4062
# Q24.1719 66.4062 20.3281 58.9062
# Q16.5 51.4219 16.5 36.375
# Q16.5 21.3906 20.3281 13.8906
# Q24.1719 6.39062 31.7812 6.39062
# Q39.4531 6.39062 43.2812 13.8906
# Q47.125 21.3906 47.125 36.375
# Q47.125 51.4219 43.2812 58.9062
# Q39.4531 66.4062 31.7812 66.4062
# M31.7812 74.2188
# Q44.0469 74.2188 50.5156 64.5156
# Q56.9844 54.8281 56.9844 36.375
# Q56.9844 17.9688 50.5156 8.26562
# Q44.0469 -1.42188 31.7812 -1.42188
# Q19.5312 -1.42188 13.0625 8.26562
# Q6.59375 17.9688 6.59375 36.375
# Q6.59375 54.8281 13.0625 64.5156
# Q19.5312 74.2188 31.7812 74.2188" id="BitstreamVeraSans-Roman-30"/>
#        <path d="
# M10.6875 12.4062
# L21 12.4062
# L21 0
# L10.6875 0
# z
# " id="BitstreamVeraSans-Roman-2e"/>
#       </defs>
#       <g transform="translate(22.874375 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_2">
#      <g id="line2d_4">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="83.6529464286" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_5">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="83.6529464286" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_2">
#       <!-- 0.5 -->
#       <defs>
#        <path d="
# M10.7969 72.9062
# L49.5156 72.9062
# L49.5156 64.5938
# L19.8281 64.5938
# L19.8281 46.7344
# Q21.9688 47.4688 24.1094 47.8281
# Q26.2656 48.1875 28.4219 48.1875
# Q40.625 48.1875 47.75 41.5
# Q54.8906 34.8125 54.8906 23.3906
# Q54.8906 11.625 47.5625 5.09375
# Q40.2344 -1.42188 26.9062 -1.42188
# Q22.3125 -1.42188 17.5469 -0.640625
# Q12.7969 0.140625 7.71875 1.70312
# L7.71875 11.625
# Q12.1094 9.23438 16.7969 8.0625
# Q21.4844 6.89062 26.7031 6.89062
# Q35.1562 6.89062 40.0781 11.3281
# Q45.0156 15.7656 45.0156 23.3906
# Q45.0156 31 40.0781 35.4375
# Q35.1562 39.8906 26.7031 39.8906
# Q22.75 39.8906 18.8125 39.0156
# Q14.8906 38.1406 10.7969 36.2812
# z
# " id="BitstreamVeraSans-Roman-35"/>
#       </defs>
#       <g transform="translate(77.9048214286 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-30"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_3">
#      <g id="line2d_6">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="138.599642857" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_7">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="138.599642857" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_3">
#       <!-- 1.0 -->
#       <defs>
#        <path d="
# M12.4062 8.29688
# L28.5156 8.29688
# L28.5156 63.9219
# L10.9844 60.4062
# L10.9844 69.3906
# L28.4219 72.9062
# L38.2812 72.9062
# L38.2812 8.29688
# L54.3906 8.29688
# L54.3906 0
# L12.4062 0
# z
# " id="BitstreamVeraSans-Roman-31"/>
#       </defs>
#       <g transform="translate(132.943392857 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_4">
#      <g id="line2d_8">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="193.546339286" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_9">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="193.546339286" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_4">
#       <!-- 1.5 -->
#       <g transform="translate(187.973839286 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-31"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-35"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_5">
#      <g id="line2d_10">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="248.493035714" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="line2d_11">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="248.493035714" xlink:href="#m741efc42ff" y="25.078125"/>
#       </g>
#      </g>
#      <g id="text_5">
#       <!-- 2.0 -->
#       <defs>
#        <path d="
# M19.1875 8.29688
# L53.6094 8.29688
# L53.6094 0
# L7.32812 0
# L7.32812 8.29688
# Q12.9375 14.1094 22.625 23.8906
# Q32.3281 33.6875 34.8125 36.5312
# Q39.5469 41.8438 41.4219 45.5312
# Q43.3125 49.2188 43.3125 52.7812
# Q43.3125 58.5938 39.2344 62.25
# Q35.1562 65.9219 28.6094 65.9219
# Q23.9688 65.9219 18.8125 64.3125
# Q13.6719 62.7031 7.8125 59.4219
# L7.8125 69.3906
# Q13.7656 71.7812 18.9375 73
# Q24.125 74.2188 28.4219 74.2188
# Q39.75 74.2188 46.4844 68.5469
# Q53.2188 62.8906 53.2188 53.4219
# Q53.2188 48.9219 51.5312 44.8906
# Q49.8594 40.875 45.4062 35.4062
# Q44.1875 33.9844 37.6406 27.2188
# Q31.1094 20.4531 19.1875 8.29688" id="BitstreamVeraSans-Roman-32"/>
#       </defs>
#       <g transform="translate(242.690535714 258.7625)scale(0.08 -0.08)">
#        <use xlink:href="#BitstreamVeraSans-Roman-32"/>
#        <use x="63.623046875" xlink:href="#BitstreamVeraSans-Roman-2e"/>
#        <use x="95.41015625" xlink:href="#BitstreamVeraSans-Roman-30"/>
#       </g>
#      </g>
#     </g>
#     <g id="xtick_6">
#      <g id="line2d_12">
#       <g>
#        <use style="stroke:#000000;stroke-width:0.5;" x="303.439732143" xlink:href="#m93b0483c22" y="248.68375"/>
#       </g>
#      </g>
#      <g id="lin

# %% [markdown]
# El escenario descrito anteriormente es lo que constituye a la bifurcación silla-nodo o tangente.
#
# Formalmente, tenems que la bifurcación de silla-nodo para una familia monoparamétrica $F_\lambda$ ocurre en $\lambda_0$, cuando existe un intervalo *abierto* $I$ y un $\epsilon>0$ tal que:
#
# 1. Para $\lambda_0-\epsilon<\lambda<\lambda_0$ no hay puntos fijos de $F_\lambda$ en $I$.
#
# 1. Para $\lambda=\lambda_0$ existe un sólo punto fijo de $F_\lambda$ en $I$ y éste es neutral.
#
# 1. Para $\lambda_0<\lambda<\lambda_0+\epsilon$ tenemos dos puntos fijos de de $F_\lambda$, uno es repulsivo y el otro es atractivo.
#
#
# Hay dos puntos importantes que vale la pena enfatizar. Primero, la bifurcación de silla-nodo ocurre cuando $F_{\lambda_0}(x)$ tiene una tancencia cuadrática con la diagonal, es decir, $F'_{\lambda_0}(x_0)=1$ y $F''_{\lambda_0}(x_0)\ne 0$. Esto es, localmente $F_{\lambda_0}$ es cóncava o convexa.
#
# El segundo punto es que la teoría de bifurcaciones es una teoría local alrededor del parámetro $\lambda_0$. Es por eso que la definición incluye $\epsilon>0$. La teoría no dice nada de qué puede pasar lejos de $\lambda_0$.

# %% [markdown]
# Técnicamente, $F_\lambda(x) = \lambda x(1-x)$ **no** tiene una bifurcación silla-nodo en $\lambda_0=1$, a pesar de que $F'{\lambda_0}(0)=1, F''{\lambda_0}(0)\ne 0$. La razón es que $x_0=0$ es un punto fijo a ambos lados de $\lambda_0$.

# %% [markdown]
# ## Otro tipo de bifurcación

# %% [markdown]
# Siguiendo con el ejemplo de la familia quadrática $Q_c(x)$, en $c=-3/4$ *otra* bifurcación ocurre, y ésta está relacionada con el cambio de estabilidad de $p_-(c)$.
#
# Al volverse repulsor $p_-(c)$, es decir $c<-3/4$, como sugiere la siguiente figura, *aparece* un ciclo de periodo 2 que, de hecho, es estable.

# %% [markdown]
# ```julia
# Qc(x,c) = x^2 + c       # Mapeo cuadrático
# qc1 = x -> Qc(x, -0.5)  # Mapeo cuadrático con c = 0.5
# qc2 = x -> Qc(x, -0.76)  # Mapeo cuadrático con c = 0.5
#
# p = plot(domx, qc1, xaxis=(L"x", ), yaxis=L"Q_c(x)", label=L"Q_{-0.5}(x)")
# plot!(domx, qc2, xaxis=(L"x", ), yaxis=L"Q_c(x)", label=L"Q_{-1}(x)")
# plot!(domx, identity, xaxis=(L"x"), label=L"Id(x)", color=:red)
#
# vx, vqc1 = iteramapeo(qc1, 1/256, 4)
# plot!(p, vx, vqc1, marker=(:dot,3,0.4), label="", color=:green, line=:dot)
#
# vx, vqc2 = iteramapeo(qc2, 1/256, 4)
# plot!(p, vx, vqc2, marker=(:dot,3,0.4), label="", color=:green)
#
# png("fig07-3")
# ```

# %% [markdown]
# ![](fig07-3.png)

# %% [markdown]
# Para entender esto, obviamente tenemos que analizar el mapeo $Q^2_c(x)$. Tenemos que
#
# \begin{equation}
# Q^2_c(x) = (x^2+c)^2+c = x^4 + 2cx^2 + c^2+c.
# \end{equation}
#
# Los puntos fijos de esta ecuación satisfacen:
#
# \begin{equation}
# Q^2_c(x) -x = (x^2+c)^2+c = x^4 + 2cx^2 - x + c^2+c = 0.
# \end{equation}

# %% [markdown]
# Para $c<-3/4$ sabemos que dos soluciones de esta ecuación son $p_+(c)$ y $p_-(c)$, ya que los puntos fijos de $Q_c(x)$ también son puntos fijos del mapeo $Q^2_c(x)$.
#
# Por lo tanto, $x-p_+(c)$ y $x-p_-(c)$ factorizan a $Q^2_c(x) -x$. Entonces, podemos escribir:
#
# \begin{equation}
# Q^2_c(x) -x = (x-p_+(c))(x-p_-(c))(x^2+x+c+1) = 0,
# \end{equation}
#
# de donde obtenemos las soluciones
#
# \begin{eqnarray}
# q_+(c) & = & \frac{1}{2}( -1 + \sqrt{-3-4c} ),\\
# q_-(c) & = & \frac{1}{2}( -1 - \sqrt{-3-4c} ).\\
# \end{eqnarray}
#
# Claramente, $q_\pm(c)$ son reales si $-3-4c\ge$, es decir, si $c\le-3/4$. Cuando $c=-3/4$ tenemos que $q_\pm(-3/4) = p_-(-3/4)$, es decir, los nuevos puntos fijos de $Q^2_c(x)$ se originan en $p_-(-3/4)$.

# %% [markdown]
# En cuanto a la estabilidad, como vimos antes, para puntos periódicos ésta viene dada por
#
# \begin{equation}
# {Q^2}'(q_+(c)) = {Q_c^2}'(q_-(c)) = Q_c'(q_+(c)) Q_c'(q_-(c)) = 4 q_+(c) q_-(c) = -2-4c.
# \end{equation}

# %% [markdown]
# Por lo tanto, en el momento de aparecer la órbita de periodo 2, ésta es neutral: ${Q^2}'(q_\pm(-3/4)) = 1$. De aquí, además, podemos ver que que,
# para $-5/4<c<-3/4$, el ciclo de periodo 2 es atractivo, ya que $|{Q^2}'(q_\pm(c))|<1$, mientras que para $c<-5/4$, el ciclo es repulsivo.

# %% [markdown]
# ```julia
# pplus(c) = 0.5*(1+sqrt(1-4*c))
# pminus(c) = 0.5*(1-sqrt(1-4*c))
#
# domc = -2:1/64:1/4
#
# plot(-2:1/64:1/4, pplus, xaxis=(L"c", (-2,1)), yaxis=(L"p_\pm(c), q_\pm(c)"), color=:red)
# plot!(-3/4:1/64:1/4, pminus, color=:blue, legend=:false)
# plot!(-2:1/64:-3/4, pminus, color=:red, line=(:dash))
#
# qplus(c) = 0.5*(-1+sqrt(-3-4*c))
# qminus(c) = 0.5*(-1-sqrt(-3-4*c))
#
# plot!(-5/4:1/64:-3/4, qplus, color=:blue)
# plot!(-5/4:1/64:-3/4, qminus, color=:blue)
# plot!(-2:1/64:-5/4, qplus, color=:red, line=(:dash))
# plot!(-2:1/64:-5/4, qminus, color=:red, line=(:dash))
#
# png("fig07-4")
# ```

# %% [markdown]
# ![](fig07-4.png)

# %% [markdown]
# La bifurcación que acabamos de describir se llama, como es de esperarse, *bifurcación de doblamiento de periodo*.
#
# De manera más formal, una bifurcación de doblamiento de periodo para una familia monoparamétrica de mapeos $F_\lambda$ ocurren en $\lambda_0$ si existe un intervalo *abierto* $I$ y un $\epsilon>0$ tal que:
#
# 1. Para toda $\lambda$ en el intervalo $[\lambda_0-\epsilon, \lambda_0+\epsilon]$ existe un único punto fijo $p_\lambda$ en $I$.
#
# 1. Para $\lambda_0-\epsilon<\lambda<\lambda_0$, el mapeo $F_\lambda$ no tiene ciclos de periodo 2 en $I$ y $p_\lambda$ es un atractor (respectivamente repulsor).
#
# 1. Para $\lambda_0<\lambda<\lambda_0+\epsilon$, existe un ciclo de periodo 2 en I para el mapeo el mapeo $F_\lambda$, que denotamos por $q_\lambda^1$ y $q_\lambda^2$, que es atractivo (respectivamente repulsivo), y el punto fijo $p_\lambda$ es repulso (respectivamente atractor).
#
# 1. En el límite $\lambda\to\lambda_0^+$, tenemos que $q_\lambda^i\to p_\lambda$.

# %% [markdown]
# Esto es, al cambiar el parámetro, un punto fijo cambia de estabilidad (de atractivo pasa a ser repulsivo, o viceversa), y al cambiar de estabilidad da lugar a la aparición de una órbita de periodo dos que tiene la estabilidad que tenía el punto fijo antes de la bifurcación.
#
# La dirección de las desigualdades (o la forma en que cambiamos el parámetro) es irrelevante.
#
# La bifurcación de doblamiento de periodo ocurre cuando $F_\lambda(x)$ es perpendicular a la diagonal, es decir, $F_{\lambda_0}'(p_{\lambda_0})=-1$.
# Usando la regla de la cadena tenemos que ${F^2_{\lambda_0}}''(p_{\lambda_0})=1$.

# %% [markdown]
# **Ejercicio 2:**
#
# - Obtengan numéricamente el diagrama de bifurcación del mapeo $Q_c(x)$ a partir de la iteración de una condición inicial en el intervalo de parámetros $-2<c<1/4$. Para esto se necesita iterar un gran número de veces (hasta llegar al ciclo periódico) condiciones iniciales, y repetir esto para *muchos* valores de $c$ en el intervalo. Vale la pena hacer notar que, si hay ciclos periódicos, *a priori* no conocen su periodicidad.
#
# - Para ciertos valores de $c$ característicos, muestren el análisis gráfico del mapeo $Q_c(x)$ a fin de entender los resultados.

# %%
function bif_qc2(n::Int64, cn::Int64, cnn::Int64) #n es el número de iteraciones      

    qc_c = Float64[] 
    qc_p = Float64[]
    
    x0 = collect(linspace(-2,1/4,cn))
    c = collect(linspace(-2,1/4,cn))


    #Qc = x0^ + c
    
    for i in 1:cn
        for j in 1:cn
        
        Qc = (x0[i])^2 + c[j]
    
        push!(qc_c, x0)
        push!(qc_p, Qc)
    
        for i in 2:n
        
            Qc = Qc^2 + c
        
            push!(qc_c, c)
            push!(qc_p, Qc)
        
        end
        end
    
    end
    
    return qc_c, qc_p
end
# Out:
# bif_qc2 (generic function with 3 methods)

# %%
bif_qc2(2,0.0,2)
# Out:
# LoadError: UndefVarError: c not defined
# while loading In[53], in expression starting on line 1
#
#  in bif_qc2 at In[42]:12

# %%
linspace(-2,2,5)
# Out:
# linspace(-2.0,2.0,5)

# %%
cond=collect(linspace(-2,2,5))
# Out:
# 5-element Array{Float64,1}:
#  -2.0
#  -1.0
#   0.0
#   1.0
#   2.0

# %%
cond[1]
# Out:
# -2.0
